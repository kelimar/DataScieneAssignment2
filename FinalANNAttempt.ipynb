# %%
# ANN MODEL EXPERIMENTS

# %%
# reading in the dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
shopping_datasetANN = pd.read_csv('shopping_trends_updated.csv')
shopping_datasetANN.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0        Express              Yes             Yes                  14
# 1        Express              Yes             Yes                   2
# 2  Free Shipping              Yes             Yes                  23
# 3   Next Day Air              Yes             Yes                  49
# 4  Free Shipping              Yes             Yes                  31
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually

# %%
# sum of null values, should be 0 is no null values
shopping_datasetANN.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
# sum of any duplicates
duplicate_set = shopping_datasetANN.duplicated().sum()
print(f'Duplicated rows in shoppping dataset: {duplicate_set}')
# Out:
# Duplicated rows in shoppping dataset: 0

# %%
# check for outliers
from scipy import stats
z_scores = np.abs(stats.zscore(shopping_datasetANN.select_dtypes(include=[np.number])))
outliers = (z_scores > 3).any(axis=1)
print(f'Number of outliers: {outliers.sum()}')
# Out:
# Number of outliers: 0

# %%
# double check what columns are in the dataset
print(shopping_datasetANN.columns)
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
# question - predicting subscription status
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models, Input
import matplotlib.pyplot as plt
import seaborn as sns

# organising features
features = shopping_datasetANN[['Age', 'Gender', 'Purchase Amount (USD)', 'Previous Purchases', 'Frequency of Purchases']]
target = shopping_datasetANN['Subscription Status']

# convert categorical data
features.loc[:, 'Gender'] = LabelEncoder().fit_transform(features['Gender'])
features.loc[:, 'Frequency of Purchases'] = LabelEncoder().fit_transform(features['Frequency of Purchases'])
target = target.map({'Yes': 1, 'No': 0})  # Adjust mapping based on actual values

# scale features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# define ANN model
def create_model():
    model = models.Sequential([
        Input(shape=(scaled_features.shape[1],)),
        layers.Dense(64, activation='relu'),
        layers.Dense(32, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
accuracies = []
maes = []
mses = []

for train_index, test_index in kf.split(scaled_features):
    X_train, X_test = scaled_features[train_index], scaled_features[test_index]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]

    model = create_model()
    history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=0)

    y_pred = (model.predict(X_test) > 0.5).astype("int32")
    accuracies.append(accuracy_score(y_test, y_pred))
    maes.append(mean_absolute_error(y_test, y_pred))
    mses.append(mean_squared_error(y_test, y_pred))

# average metrics
print(f'Average Accuracy: {np.mean(accuracies):.2f}')
print(f'Average Mean Absolute Error: {np.mean(maes):.2f}')
print(f'Average Mean Squared Error: {np.mean(mses):.2f}')

# final model training on entire dataset
X_train, X_test, y_train, y_test = train_test_split(scaled_features, target, test_size=0.2, random_state=42)
model = create_model()
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)

# evaluate the final model
y_pred = (model.predict(X_test) > 0.5).astype("int32")
accuracy = accuracy_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print(f'Final Model Accuracy: {accuracy:.2f}')
print(f'Final Model Mean Absolute Error: {mae:.2f}')
print(f'Final Model Mean Squared Error: {mse:.2f}')
print("Final Model Classification Report:")
print(classification_report(y_test, y_pred))

# confusion Matrix as a heatmap
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix Heatmap')
plt.show()

# visualize training history
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Average Accuracy: 0.72
# Average Mean Absolute Error: 0.28
# Average Mean Squared Error: 0.28
# Epoch 1/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6676 - loss: 0.6201 - val_accuracy: 0.7452 - val_loss: 0.4915
# Epoch 2/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7293 - loss: 0.4915 - val_accuracy: 0.7404 - val_loss: 0.4482
# Epoch 3/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7192 - loss: 0.4672 - val_accuracy: 0.7388 - val_loss: 0.4432
# Epoch 4/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7254 - loss: 0.4570 - val_accuracy: 0.7404 - val_loss: 0.4404
# Epoch 5/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7317 - loss: 0.4501 - val_accuracy: 0.7404 - val_loss: 0.4387
# Epoch 39/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7399 - loss: 0.4457 - val_accuracy: 0.7468 - val_loss: 0.4417
# Epoch 40/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7415 - loss: 0.4440 - val_accuracy: 0.7452 - val_loss: 0.4394
# Epoch 41/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7314 - loss: 0.4462 - val_accuracy: 0.7484 - val_loss: 0.4409
# Epoch 42/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7405 - loss: 0.4391 - val_accuracy: 0.7404 - val_loss: 0.4407
# Epoch 43/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7371 - loss: 0.4431 - val_accuracy: 0.7324 - val_loss: 0.4416
# Epoch 44/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7423 - loss: 0.4437 - val_accuracy: 0.7404 - val_loss: 0.4421
# Epoch 45/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7351 - loss: 0.4433 - val_accuracy: 0.7452 - val_loss: 0.4424
# Epoch 46/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7456 - loss: 0.4383 - val_accuracy: 0.7356 - val_loss: 0.4407
# Epoch 47/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7412 - loss: 0.4403 - val_accuracy: 0.7115 - val_loss: 0.4448
# Epoch 48/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7173 - loss: 0.4429 - val_accuracy: 0.7404 - val_loss: 0.4428
# Epoch 49/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7298 - loss: 0.4588 - val_accuracy: 0.7500 - val_loss: 0.4401
# Epoch 50/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7339 - loss: 0.4514 - val_accuracy: 0.7436 - val_loss: 0.4458
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Final Model Accuracy: 0.72
# Final Model Mean Absolute Error: 0.28
# Final Model Mean Squared Error: 0.28
# Final Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.99      0.83       558
#            1       0.57      0.02      0.03       222
#
#     accuracy                           0.72       780
#    macro avg       0.64      0.51      0.43       780
# weighted avg       0.68      0.72      0.61       780

# %%
# question - preferred products across customer segments
# preprocess for feature select
features = shopping_datasetANN[['Age', 'Gender', 'Location']]
target = shopping_datasetANN['Item Purchased']

# encode categorical variables
features.loc[:, 'Gender'] = LabelEncoder().fit_transform(features['Gender'])
features.loc[:, 'Location'] = LabelEncoder().fit_transform(features['Location'])
target = LabelEncoder().fit_transform(target)

# scale the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# define ANN model
def create_model():
    model = models.Sequential([
        Input(shape=(scaled_features.shape[1],)),
        layers.Dense(64, activation='relu'),
        layers.Dense(32, activation='relu'),
        layers.Dense(len(np.unique(target)), activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
accuracies = []
maes = []
mses = []

for train_index, test_index in kf.split(scaled_features):
    X_train, X_test = scaled_features[train_index], scaled_features[test_index]
    y_train, y_test = target[train_index], target[test_index]

    model = create_model()
    history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=0)

    y_pred = np.argmax(model.predict(X_test), axis=1)
    accuracies.append(accuracy_score(y_test, y_pred))
    maes.append(mean_absolute_error(y_test, y_pred))
    mses.append(mean_squared_error(y_test, y_pred))

# average metrics
print(f'Average Accuracy: {np.mean(accuracies):.2f}')
print(f'Average Mean Absolute Error: {np.mean(maes):.2f}')
print(f'Average Mean Squared Error: {np.mean(mses):.2f}')

# final model training on the entire dataset
X_train, X_test, y_train, y_test = train_test_split(scaled_features, target, test_size=0.2, random_state=42)
model = create_model()
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)

# evaluate the final model
y_pred = np.argmax(model.predict(X_test), axis=1)
accuracy = accuracy_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print(f'Final Model Accuracy: {accuracy:.2f}')
print(f'Final Model Mean Absolute Error: {mae:.2f}')
print(f'Final Model Mean Squared Error: {mse:.2f}')
print("Final Model Classification Report:")
print(classification_report(y_test, y_pred))

# confusion Matrix as a heatmap
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix Heatmap')
plt.show()

# visualize training history
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Average Accuracy: 0.04
# Average Mean Absolute Error: 8.35
# Average Mean Squared Error: 104.12
# Epoch 1/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.
50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0651 - loss: 3.1639 - val_accuracy: 0.0337 - val_loss: 3.2763
# Epoch 34/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0703 - loss: 3.1487 - val_accuracy: 0.0304 - val_loss: 3.2747
# Epoch 35/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0713 - loss: 3.1474 - val_accuracy: 0.0304 - val_loss: 3.2769
# Epoch 36/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0664 - loss: 3.1447 - val_accuracy: 0.0321 - val_loss: 3.2803
# Epoch 37/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0691 - loss: 3.1505 - val_accuracy: 0.0321 - val_loss: 3.2774
# Epoch 38/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0633 - loss: 3.1483 - val_accuracy: 0.0337 - val_loss: 3.2810
# Epoch 39/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.0784 - loss: 3.1451 - val_accuracy: 0.0353 - val_loss: 3.2832
# Epoch 40/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0722 - loss: 3.1407 - val_accuracy: 0.0321 - val_loss: 3.2820
# Epoch 41/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0669 - loss: 3.1518 - val_accuracy: 0.0321 - val_loss: 3.2817
# Epoch 42/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0698 - loss: 3.1448 - val_accuracy: 0.0337 - val_loss: 3.2844
# Epoch 43/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0721 - loss: 3.1396 - val_accuracy: 0.0304 - val_loss: 3.2851
# Epoch 44/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0755 - loss: 3.1301 - val_accuracy: 0.0369 - val_loss: 3.2881
# Epoch 45/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0672 - loss: 3.1428 - val_accuracy: 0.0321 - val_loss: 3.2874
# Epoch 46/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0840 - loss: 3.1376 - val_accuracy: 0.0369 - val_loss: 3.2930
# Epoch 47/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0686 - loss: 3.1410 - val_accuracy: 0.0353 - val_loss: 3.2921
# Epoch 48/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0738 - loss: 3.1435 - val_accuracy: 0.0369 - val_loss: 3.2899
# Epoch 49/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0809 - loss: 3.1289 - val_accuracy: 0.0353 - val_loss: 3.2894
# Epoch 50/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0812 - loss: 3.1324 - val_accuracy: 0.0337 - val_loss: 3.2901
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Final Model Accuracy: 0.04
# Final Model Mean Absolute Error: 7.87
# Final Model Mean Squared Error: 92.20
# Final Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        26
#            1       0.12      0.05      0.07        40
#            2       0.03      0.03      0.03        33
#            3       0.04      0.03      0.03        36
#            4       0.05      0.03      0.04        31
#            5       0.03      0.03      0.03        31
#            6       0.00      0.00      0.00        27
#            7       0.00      0.00      0.00        34
#            8       0.00      0.00      0.00        36
#            9       0.06      0.04      0.05        24
#           10       0.00      0.00      0.00        32
#           11       0.00      0.00      0.00        28
#           12       0.04      0.21      0.06        28
#           13       0.03      0.03      0.03        36
#           14       0.04      0.10      0.06        29
#           15       0.05      0.04      0.04        24
#           16       0.03      0.05      0.04        44
#           17       0.03      0.04      0.03        25
#           18       0.00      0.00      0.00        23
#           19       0.03      0.07      0.04        29
#           20       0.07      0.03      0.04        32
#           21       0.12      0.09      0.10        34
#           22       0.03      0.09      0.05        34
#           23       0.00      0.00      0.00        32
#           24       0.00      0.00      0.00        32
#
#     accuracy                           0.04       780
#    macro avg       0.03      0.04      0.03       780
# weighted avg       0.03      0.04      0.03       780
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# question - how do purchasing patterns vary by season

import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import accuracy_score, mean_absolute_error, mean_squared_error, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from keras import models, layers

# preprocess the data
features = shopping_datasetANN[['Purchase Amount (USD)', 'Category', 'Discount Applied']]
target = shopping_datasetANN['Season']

# encode categorical variables
features.loc[:, 'Category'] = LabelEncoder().fit_transform(features['Category'])
features.loc[:, 'Discount Applied'] = LabelEncoder().fit_transform(features['Discount Applied'])
target = LabelEncoder().fit_transform(target)

# scale the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# define ANN model
def create_model():
    model = models.Sequential([
        Input(shape=(scaled_features.shape[1],)),
        layers.Dense(64, activation='relu'),
        layers.Dense(32, activation='relu'),
        layers.Dense(len(np.unique(target)), activation='softmax')
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
accuracies = []
maes = []
mses = []

for train_index, test_index in kf.split(scaled_features):
    X_train, X_test = scaled_features[train_index], scaled_features[test_index]
    y_train, y_test = target[train_index], target[test_index]

    model = create_model()
    history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=0)

    y_pred = np.argmax(model.predict(X_test), axis=1)
    accuracies.append(accuracy_score(y_test, y_pred))
    maes.append(mean_absolute_error(y_test, y_pred))
    mses.append(mean_squared_error(y_test, y_pred))

# average metrics
print(f'Average Accuracy: {np.mean(accuracies):.2f}')
print(f'Average Mean Absolute Error: {np.mean(maes):.2f}')
print(f'Average Mean Squared Error: {np.mean(mses):.2f}')

# final model training on the entire dataset
X_train, X_test, y_train, y_test = train_test_split(scaled_features, target, test_size=0.2, random_state=42)
model = create_model()
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)

# evaluate the final model
y_pred = np.argmax(model.predict(X_test), axis=1)
accuracy = accuracy_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print(f'Final Model Accuracy: {accuracy:.2f}')
print(f'Final Model Mean Absolute Error: {mae:.2f}')
print(f'Final Model Mean Squared Error: {mse:.2f}')
print("Final Model Classification Report:")
print(classification_report(y_test, y_pred))

# confusion Matrix as a heatmap
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix Heatmap')
plt.show()

# visualize training history
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Average Accuracy: 0.25
# Average Mean Absolute Error: 1.26
# Average Mean Squared Error: 2.56
# Epoch 1/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2438 - loss: 1.4018 - val_accuracy: 0.2388 - val_loss: 1.3879
# Epoch 2/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2679 - loss: 1.3821 - val_accuracy: 0.2468 - val_loss: 1.3885
# Epoch 3/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2650 - loss: 1.3813 - val_accuracy: 0.2484 - val_loss: 1.3884
# Epoch 4/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2793 - loss: 1.3788 - val_accuracy: 0.2500 - val_loss: 1.3865
# Epoch 5/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2846 - loss: 1.3757 - val_accuracy: 0.2612 - val_loss: 1.3889
# Epoch 6/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2946 - loss: 1.3764 - val_accuracy: 0.2436 - val_loss: 1.3895
# Epoch 7/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.2810 - loss: 1.3770 - val_accuracy: 0.2548 - val_loss: 1.3888
# Epoch 8/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2852 - loss: 1.3739 - val_accuracy: 0.2548 - val_loss: 1.3898
# Epoch 9/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2900 - loss: 1.3781 - val_accuracy: 0.2532 - val_loss: 1.3894
# Epoch 10/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2952 - loss: 1.3725 - val_accuracy: 0.2500 - val_loss: 1.3874
# Epoch 11/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3056 - loss: 1.3738 - val_accuracy: 0.2548 - val_loss: 1.3874
# Epoch 12/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2915 - loss: 1.3738 - val_accuracy: 0.2788 - val_loss: 1.3864
# Epoch 13/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2866 - loss: 1.3715 - val_accuracy: 0.2564 - val_loss: 1.3870
# Epoch 14/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2997 - loss: 1.3759 - val_accuracy: 0.2532 - val_loss: 1.3875
# Epoch 15/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2963 - loss: 1.3741 - val_accuracy: 0.2452 - val_loss: 1.3865
# Epoch 16/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3061 - loss: 1.3707 - val_accuracy: 0.2548 - val_loss: 1.3870
# Epoch 17/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2990 - loss: 1.3718 - val_accuracy: 0.2821 - val_loss: 1.3875
# Epoch 18/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2851 - loss: 1.3754 - val_accuracy: 0.2484 - val_loss: 1.3875
# Epoch 19/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2989 - loss: 1.3728 - val_accuracy: 0.2548 - val_loss: 1.3878
# Epoch 20/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.
model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.31      0.28      0.29       215
#            1       0.24      0.17      0.20       201
#            2       0.24      0.26      0.25       190
#            3       0.24      0.33      0.28       174
#
#     accuracy                           0.26       780
#    macro avg       0.26      0.26      0.26       780
# weighted avg       0.26      0.26      0.26       780

# %%
# question - predict product demand from frequency

# preprocess for feature select
features = shopping_datasetANN[['Previous Purchases', 'Frequency of Purchases']]
target = shopping_datasetANN['Purchase Amount (USD)']

# encode categorical variables
features.loc[:, 'Frequency of Purchases'] = LabelEncoder().fit_transform(features['Frequency of Purchases'])

# scale the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# define the ANN model
def create_model():
    model = models.Sequential([
        Input(shape=(scaled_features.shape[1],)),
        layers.Dense(64, activation='relu'),
        layers.Dense(32, activation='relu'),
        layers.Dense(1)
    ])
    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae', 'mse'])
    return model

# cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
maes = []
mses = []

for train_index, test_index in kf.split(scaled_features):
    X_train, X_test = scaled_features[train_index], scaled_features[test_index]
    y_train, y_test = target.iloc[train_index], target.iloc[test_index]

    model = create_model()
    history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=0)

    y_pred = model.predict(X_test)
    maes.append(mean_absolute_error(y_test, y_pred))
    mses.append(mean_squared_error(y_test, y_pred))

# average metrics
print(f'Average Mean Absolute Error: {np.mean(maes):.2f}')
print(f'Average Mean Squared Error: {np.mean(mses):.2f}')

# final model training on the entire dataset
X_train, X_test, y_train, y_test = train_test_split(scaled_features, target, test_size=0.2, random_state=42)
model = create_model()
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)

# evaluate the final model
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print(f'Final Model Mean Absolute Error: {mae:.2f}')
print(f'Final Model Mean Squared Error: {mse:.2f}')

# visualize training history
plt.figure(figsize=(12, 6))
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.title('Training and Validation Mean Absolute Error')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(history.history['mse'], label='Training MSE')
plt.plot(history.history['val_mse'], label='Validation MSE')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.title('Training and Validation Mean Squared Error')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Average Mean Absolute Error: 20.67
# Average Mean Squared Error: 565.44
# Epoch 1/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4066.1479 - mae: 59.1277 - mse: 4066.1479 - val_loss: 3378.2808 - val_mae: 53.1767 - val_mse: 3378.2808
# Epoch 2/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3022.1790 - mae: 49.2951 - mse: 3022.1790 - val_loss: 1435.5406 - val_mae: 30.8498 - val_mse: 1435.5406
# Epoch 3/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1104.2120 - mae: 27.2033 - mse: 1104.2120 - val_loss: 649.0880 - val_mae: 21.5996 - val_mse: 649.0880
# Epoch 4/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 643.3686 - mae: 21.5264 - mse: 643.3686 - val_loss: 630.2502 - val_mae: 21.3872 - val_mse: 630.2502
# Epoch 5/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 624.5009 - mae: 21.2833 - mse: 624.5009 - val_loss: 616.1642 - val_mae: 21.1914 - val_mse: 616.1642
# Epoch 6/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 609.5339 - mae: 21.0457 - mse: 609.5339 - val_loss: 603.8090 - val_mae: 21.0190 - val_mse: 603.8090
# Epoch 7/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 614.9863 - mae: 21.3009 - mse: 614.9863 - val_loss: 594.2003 - val_mae: 20.9203 - val_mse: 594.2003
# Epoch 8/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 588.1537 - mae: 20.8700 - mse: 588.1537 - val_loss: 584.5103 - val_mae: 20.8128 - val_mse: 584.5103
# Epoch 9/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 590.8787 - mae: 20.9648 - mse: 590.8787 - val_loss: 579.7694 - val_mae: 20.7635 - val_mse: 579.7694
# Epoch 10/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 560.3281 - mae: 20.1928 - mse: 560.3281 - val_loss: 576.0018 - val_mae: 20.6815 - val_mse: 576.0018
# Epoch 11/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 572.5246 - mae: 20.5531 - mse: 572.5246 - val_loss: 569.4005 - val_mae: 20.6132 - val_mse: 569.4005
# Epoch 12/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss:
50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 565.2869 - mae: 20.6066 - mse: 565.2869 - val_loss: 554.2111 - val_mae: 20.5298 - val_mse: 554.2111
# Epoch 35/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 556.7706 - mae: 20.2737 - mse: 556.7706 - val_loss: 550.3095 - val_mae: 20.4624 - val_mse: 550.3095
# Epoch 36/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 564.5556 - mae: 20.6347 - mse: 564.5556 - val_loss: 552.1204 - val_mae: 20.4722 - val_mse: 552.1204
# Epoch 37/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 567.1259 - mae: 20.6451 - mse: 567.1259 - val_loss: 549.2494 - val_mae: 20.4353 - val_mse: 549.2494
# Epoch 38/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 569.5529 - mae: 20.7186 - mse: 569.5529 - val_loss: 550.7776 - val_mae: 20.4585 - val_mse: 550.7776
# Epoch 39/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 545.9848 - mae: 20.2477 - mse: 545.9848 - val_loss: 548.6273 - val_mae: 20.4372 - val_mse: 548.6273
# Epoch 40/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 558.7177 - mae: 20.5307 - mse: 558.7177 - val_loss: 551.2653 - val_mae: 20.4702 - val_mse: 551.2653
# Epoch 41/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 557.6058 - mae: 20.4465 - mse: 557.6058 - val_loss: 551.9780 - val_mae: 20.4928 - val_mse: 551.9780
# Epoch 42/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 569.3784 - mae: 20.7744 - mse: 569.3784 - val_loss: 550.7309 - val_mae: 20.4449 - val_mse: 550.7309
# Epoch 43/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 557.6484 - mae: 20.4375 - mse: 557.6484 - val_loss: 553.1268 - val_mae: 20.5189 - val_mse: 553.1268
# Epoch 44/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 556.2115 - mae: 20.3895 - mse: 556.2115 - val_loss: 548.5855 - val_mae: 20.4050 - val_mse: 548.5855
# Epoch 45/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 551.8719 - mae: 20.2131 - mse: 551.8719 - val_loss: 550.3889 - val_mae: 20.4663 - val_mse: 550.3889
# Epoch 46/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 557.8381 - mae: 20.3478 - mse: 557.8381 - val_loss: 552.4885 - val_mae: 20.4978 - val_mse: 552.4885
# Epoch 47/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 554.9263 - mae: 20.3081 - mse: 554.9263 - val_loss: 550.8842 - val_mae: 20.4892 - val_mse: 550.8842
# Epoch 48/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 565.1821 - mae: 20.5899 - mse: 565.1821 - val_loss: 553.6689 - val_mae: 20.5053 - val_mse: 553.6689
# Epoch 49/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 558.0909 - mae: 20.4203 - mse: 558.0909 - val_loss: 552.4310 - val_mae: 20.5005 - val_mse: 552.4310
# Epoch 50/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 545.6993 - mae: 20.2027 - mse: 545.6993 - val_loss: 552.6708 - val_mae: 20.5020 - val_mse: 552.6708
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Final Model Mean Absolute Error: 20.87
# Final Model Mean Squared Error: 570.10

# %%
# question - are current marketing strategies effective

import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import accuracy_score, mean_absolute_error, mean_squared_error, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from keras import models, layers

# preprocess the data
features = shopping_datasetANN[['Age', 'Gender', 'Item Purchased', 'Category', 'Purchase Amount (USD)', 'Size', 'Color', 'Shipping Type', 'Promo Code Used']]
target = shopping_datasetANN['Discount Applied']

# encode categorical variables
label_encoders = {}
for column in features.columns:
    if features[column].dtype == 'object':
        le = LabelEncoder()
        features[column] = le.fit_transform(features[column])
        label_encoders[column] = le

# encode target variable
target_encoder = LabelEncoder()
target = target_encoder.fit_transform(target)

# scale features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# define ANN model
def create_model():
    model = models.Sequential([
        Input(shape=(scaled_features.shape[1],)),
        layers.Dense(64, activation='relu'),
        layers.Dense(32, activation='relu'),
        layers.Dense(2, activation='softmax')  # Assuming binary classification
    ])
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
accuracies = []
maes = []
mses = []

for train_index, test_index in kf.split(scaled_features):
    X_train, X_test = scaled_features[train_index], scaled_features[test_index]
    y_train, y_test = target[train_index], target[test_index]

    model = create_model()
    history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=0)

    y_pred = np.argmax(model.predict(X_test), axis=1)
    accuracies.append(accuracy_score(y_test, y_pred))
    maes.append(mean_absolute_error(y_test, y_pred))
    mses.append(mean_squared_error(y_test, y_pred))

# average metrics
print(f'Average Accuracy: {np.mean(accuracies):.2f}')
print(f'Average Mean Absolute Error: {np.mean(maes):.2f}')
print(f'Average Mean Squared Error: {np.mean(mses):.2f}')

# final model training on the entire dataset
X_train, X_test, y_train, y_test = train_test_split(scaled_features, target, test_size=0.2, random_state=42)
model = create_model()
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)

# evaluate the final model
y_pred = np.argmax(model.predict(X_test), axis=1)
accuracy = accuracy_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print(f'Final Model Accuracy: {accuracy:.2f}')
print(f'Final Model Mean Absolute Error: {mae:.2f}')
print(f'Final Model Mean Squared Error: {mse:.2f}')
print("Final Model Classification Report:")
print(classification_report(y_test, y_pred))

# confusion Matrix as a heatmap
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix Heatmap')
plt.show()

# visualize training history
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-49-201b83347ab0>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features[column] = le.fit_transform(features[column])
# <ipython-input-49-201b83347ab0>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features[column] = le.fit_transform(features[column])
# <ipython-input-49-201b83347ab0>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features[column] = le.fit_transform(features[column])
# <ipython-input-49-201b83347ab0>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features[column] = le.fit_transform(features[column])
# <ipython-input-49-201b83347ab0>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features[column] = le.fit_transform(features[column])
# <ipython-input-49-201b83347ab0>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features[column] = le.fit_transform(features[column])
# <ipython-input-49-201b83347ab0>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features[column] = le.fit_transform(features[column])
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Average Accuracy: 1.00
# Average Mean Absolute Error: 0.00
# Average Mean Squared Error: 0.00
# Epoch 1/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.7606 - loss: 0.5217 - val_accuracy: 1.0000 - val_loss: 0.0518
# Epoch 2/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0312 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 3/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 4/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 5/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 8.8295e-04
# Epoch 6/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.1831e-04 - val_accuracy: 1.0000 - val_loss: 6.1007e-04
# Epoch 7/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.6373e-04 - val_accuracy: 1.0000 - val_loss: 4.4592e-04
# Epoch 8/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.1253e-04 - val_accuracy: 1.0000 - val_loss: 3.3999e-04
# Epoch 9/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.1975e-04 - val_accuracy: 1.0000 - val_loss: 2.6800e-04
# Epoch 10/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.5047e-04 - val_accuracy: 1.0000 - val_loss: 2.1647e-04
# Epoch 11/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 2.0225e-04 - val_accuracy: 1.0000 - val_loss: 1.7821e-04
# Epoch 12/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.6919e-04 - val_accuracy: 1.0000 - val_loss: 1.4908e-04
# Epoch 13/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.4300e-04 - val_accuracy: 1.0000 - val_loss: 1.2666e-04
# Epoch 14/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.2746e-04 - val_accuracy: 1.0000 - val_loss: 1.0861e-04
# Epoch 15/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.0227e-04 - val_accuracy: 1.0000 - val_loss: 9.4257e-05
# Epoch 16/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 9.0580e-05 - val_accuracy: 1.0000 - val_loss: 8.2337e-05
# Epoch 17/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 7.6746e-05 - val_accuracy: 1.0000 - val_loss: 7.2496e-05
# Epoch 18/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 7.1575e-05 - val_accuracy: 1.0000 - val_loss: 6.4204e-05
# Epoch 19/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 6.3122e-05 - val_accuracy: 1.0000 - val_loss: 5.7223e-05
# Epoch 20/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 5.6559e-05 - val_accuracy: 1.0000 - val_loss: 5.1190e-05
# Epoch 21/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.8997e-05 - val_accuracy: 1.0000 - val_loss: 4.6124e-05
# Epoch 22/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.4347e-05 - val_accuracy: 1.0000 - val_loss: 4.1641e-05
# Epoch 23/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 4.0008e-05 - val_accuracy: 1.0000 - val_loss: 3.7783e-05
# Epoch 24/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.5446e-05 - val_accuracy: 1.0000 - val_loss: 3.4394e-05
# Epoch 25/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.3377e-05 - val_accuracy: 1.0000 - val_loss: 3.1368e-05
# Epoch 26/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.0837e-05 - val_accuracy: 1.0000 - val_loss: 2.8721e-05
# Epoch 27/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.7830e-05 - val_accuracy: 1.0000 - val_loss: 2.6376e-05
# Epoch 28/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.5487e-05 - val_accuracy: 1.0000 - val_loss: 2.4253e-05
# Epoch 29/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 2.3211e-05 - val_accuracy: 1.0000 - val_loss: 2.2366e-05
# Epoch 30/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 2.1691e-05 - val_accuracy: 1.0000 - val_loss: 2.0664e-05
# Epoch 31/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 1.9916e-05 - val_accuracy: 1.0000 - val_loss: 1.9121e-05
# Epoch 32/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.9034e-05 - val_accuracy: 1.0000 - val_loss: 1.7732e-05
# Epoch 33/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.7015e-05 - val_accuracy: 1.0000 - val_loss: 1.6479e-05
# Epoch 34/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.5870e-05 - val_accuracy: 1.0000 - val_loss: 1.5317e-05
# Epoch 35/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.4689e-05 - val_accuracy: 1.0000 - val_loss: 1.4266e-05
# Epoch 36/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.3628e-05 - val_accuracy: 1.0000 - val_loss: 1.3312e-05
# Epoch 37/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.2522e-05 - val_accuracy: 1.0000 - val_loss: 1.2431e-05
# Epoch 38/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.1912e-05 - val_accuracy: 1.0000 - val_loss: 1.1618e-05
# Epoch 39/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.1042e-05 - val_accuracy: 1.0000 - val_loss: 1.0875e-05
# Epoch 40/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.0478e-05 - val_accuracy: 1.0000 - val_loss: 1.0195e-05
# Epoch 41/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.6601e-06 - val_accuracy: 1.0000 - val_loss: 9.5615e-06
# Epoch 42/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 9.1869e-06 - val_accuracy: 1.0000 - val_loss: 8.9746e-06
# Epoch 43/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.5861e-06 - val_accuracy: 1.0000 - val_loss: 8.4347e-06
# Epoch 44/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.3312e-06 - val_accuracy: 1.0000 - val_loss: 7.9346e-06
# Epoch 45/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.5380e-06 - val_accuracy: 1.0000 - val_loss: 7.4635e-06
# Epoch 46/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.1548e-06 - val_accuracy: 1.0000 - val_loss: 7.0310e-06
# Epoch 47/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.6282e-06 - val_accuracy: 1.0000 - val_loss: 6.6264e-06
# Epoch 48/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 6.2999e-06 - val_accuracy: 1.0000 - val_loss: 6.2502e-06
# Epoch 49/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 6.0094e-06 - val_accuracy: 1.0000 - val_loss: 5.9014e-06
# Epoch 50/50
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.5449e-06 - val_accuracy: 1.0000 - val_loss: 5.5726e-06
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Final Model Accuracy: 1.00
# Final Model Mean Absolute Error: 0.00
# Final Model Mean Squared Error: 0.00
# Final Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       422
#            1       1.00      1.00      1.00       358
#
#     accuracy                           1.00       780
#    macro avg       1.00      1.00      1.00       780
# weighted avg       1.00      1.00      1.00       780
